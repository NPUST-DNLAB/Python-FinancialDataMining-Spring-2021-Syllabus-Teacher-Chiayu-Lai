# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
from matplotlib.font_manager import FontProperties
#font=FontProperties(fname='C:/Windows/Fonts/msyh.ttf')
# %matplotlib inline
#導入ADF函數和numpy包
import warnings
warnings.filterwarnings('ignore')
from arch.unitroot import ADF
import numpy as np
import re
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import yfinance as yf
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] #中文錯誤問題

# %%
StockSymbol = ["1102.TW","1216.TW","1301.TW","1303.TW","1326.TW","1402.TW","2002.TW","2105.TW","2207.TW","2227.TW","2301.TW","2303.TW","2308.TW","2317.TW","2330.TW","2352.TW","2354.TW","2357.TW","2382.TW","2395.TW","2408.TW","2409.TW","2412.TW","2454.TW","2474.TW","2609.TW","2610.TW","2801.TW","2823.TW","2880.TW","2881.TW","2882.TW","2883.TW","2884.TW","2885.TW","2886.TW","2887.TW","2890.TW","2891.TW","2892.TW","2912.TW","3008.TW","3045.TW","3481.TW","3711.TW","4904.TW","4938.TW","5880.TW","6505.TW","9904.TW"]
StockName = ["TW1102","TW1216","TW1301","TW1303","TW1326","TW1402","TW2002","TW2105","TW2207","TW2227","TW2301","TW2303","TW2308","TW2317","TW2330","TW2352","TW2354","TW2357","TW2382","TW2395","TW2408","TW2409","TW2412","TW2454","TW2474","TW2609","TW2610","TW2801","TW2823","TW2880","TW2881","TW2882","TW2883","TW2884","TW2885","TW2886","TW2887","TW2890","TW2891","TW2892","TW2912","TW3008","TW3045","TW3481","TW3711","TW4904","TW4938","TW5880","TW6505","TW9904"]
StockDataList = ["TW1102","TW1216","TW1301","TW1303","TW1326","TW1402","TW2002","TW2105","TW2207","TW2227","TW2301","TW2303","TW2308","TW2317","TW2330","TW2352","TW2354","TW2357","TW2382","TW2395","TW2408","TW2409","TW2412","TW2454","TW2474","TW2609","TW2610","TW2801","TW2823","TW2880","TW2881","TW2882","TW2883","TW2884","TW2885","TW2886","TW2887","TW2890","TW2891","TW2892","TW2912","TW3008","TW3045","TW3481","TW3711","TW4904","TW4938","TW5880","TW6505","TW9904"]

# %%
#最小距離法
def SSD(priceX,priceY):
    if priceX is None or priceY is None:
        print('缺少價格序列.')
    standardX=priceX/priceX[0]
    standardY=priceY/priceY[0]
    SSD=np.sum((standardX-standardY)**2)
    return(SSD)

# %%
def spreadCal(priceX,priceY):
    data = pd.concat([priceX,priceY],axis=1).dropna()
    data.columns=['X','Y']
    standardX=data.X/data.X[0]
    standardY=data.Y/data.Y[0]
    spread=standardX-standardY
    return(spread)

# %%
######PairTrading Class #############
class PairTrading:
    def SSD(self,priceX,priceY):
        if priceX is None or priceY is None:
            pass
        standardX=priceX/priceX[0]
        standardY=priceY/priceY[0]
        SSD=np.sum((standardY-standardX)**2)
        return(SSD)
    def SSDSpread(self,priceX,priceY):
        if priceX is None or priceY is None:
            pass
        standardX=priceX/priceX[0]
        standardY=priceY/priceY[0]
        spread=standardY-standardX
        return(spread)
    def cointegration(self,priceX,priceY):
        if priceX is None or priceY is None:
            print('缺少價格序列.')
        priceX=np.log(priceX)
        priceY=np.log(priceY)
        results=sm.OLS(priceY,sm.add_constant(priceX)).fit()
        resid=results.resid
        adfSpread=ADF(resid)
        if adfSpread.pvalue>=0.05:
            return(0,0,False)
        else:
            boolen = True
            print('''交易價格具有協整關係.
            P-value of ADF test: %f
            Coefficients of regression:
            Intercept: %f
            Beta: %f
             ''' % (adfSpread.pvalue, results.params[0], results.params[1]))
            return(results.params[0], results.params[1],boolen)
    def CointegrationSpread(self,priceX,priceY,
                            formStart,formEnd,tradeStart,tradeEnd):
        if priceX is None or priceY is None:
            pass
        formX=priceX[formStart:formEnd]
        formY=priceY[formStart:formEnd]
        tradeX=priceX[tradeStart:tradeEnd]
        tradeY=priceY[tradeStart:tradeEnd]
        coefficients=self.cointegration(formX,formY)
        if coefficients is None:
                pass
        else:
            spread=(np.log(tradeY)
            -coefficients[0]-coefficients[1]*np.log(tradeX))
            return(spread)
    def calBound(self,priceX,priceY,method,formStart,formEnd,width=1.5):
        formX=priceX[formStart:formEnd]
        formY=priceY[formStart:formEnd]
        if method=='SSD':
            spread=self.SSDSpread(formX,formY)            
            mu=np.mean(spread)
            sd=np.std(spread)
            UpperBound=mu+width*sd
            LowerBound=mu-width*sd
            return(UpperBound,LowerBound)
        elif method=='Cointegration':
            spread=self.CointegrationSpread(priceX,priceY,formStart,formEnd,
                 formStart,formEnd)
            mu=np.mean(spread)
            sd=np.std(spread)
            UpperBound=mu+width*sd
            LowerBound=mu-width*sd
            return(UpperBound,LowerBound)
        else:
            pass

# %%
#模擬交易
def TradeSig(prcLevel):
    n=len(prcLevel)
    signal=np.zeros(n)
    for i in range(1,n):
        if prcLevel[i-1]==1 and prcLevel[i]==2:
            signal[i]=-2
        elif prcLevel[i-1]==1 and prcLevel[i]==0:
            signal[i]=2
        elif prcLevel[i-1]==2 and prcLevel[i]==3:
            signal[i]=3
        elif prcLevel[i-1]==-1 and prcLevel[i]==-2:
            signal[i]=1
        elif prcLevel[i-1]==-1 and prcLevel[i]==0:
            signal[i]=-1
        elif prcLevel[i-1]==-2 and prcLevel[i]==-3:
            signal[i]=-3
    return(signal)

# %%
def TradeSim(priceX,priceY,position):
    n=len(position)
    shareY=10000*position
    shareX=[(-beta)*shareY[0]*priceY[0]/priceX[0]]
    cash=[10000]
    for i in range(1,n):
        shareX.append(shareX[i-1])
        cash.append(cash[i-1])
        if position[i-1]==0 and position[i]==1:
            shareX[i]=(-beta)*shareY[i]*priceY[i]/priceX[i]
            cash[i]=cash[i-1]-(shareY[i]*priceY[i]+shareX[i]*priceX[i])
        elif position[i-1]==0 and position[i]==-1:
            shareX[i]=(-beta)*shareY[i]*priceY[i]/priceX[i]
            cash[i]=cash[i-1]-(shareY[i]*priceY[i]+shareX[i]*priceX[i])
        elif position[i-1]==1 and position[i]==0:
            shareX[i]=0
            cash[i]=cash[i-1]+(shareY[i-1]*priceY[i]+shareX[i-1]*priceX[i])
        elif position[i-1]==-1 and position[i]==0:
            shareX[i]=0
            cash[i]=cash[i-1]+(shareY[i-1]*priceY[i]+shareX[i-1]*priceX[i])
    cash = pd.Series(cash,index=position.index)
    shareY=pd.Series(shareY,index=position.index)
    shareX=pd.Series(shareX,index=position.index)
    asset=cash+shareY*priceY+shareX*priceX
    account=pd.DataFrame({'Position':position,'ShareY':shareY,'ShareX':shareX,'Cash':cash,'Asset':asset})
    return(account)

# %% [markdown]
# ---

# %% [markdown]
# <font size=6>**以下是50支股票所有可配對的所有可能性**</font>

# %%
formStart='2020-01-01'
formEnd='2021-05-21'
txtarry = []
for i in range (len(StockSymbol)):
    formStart='2020-01-01'
    formEnd='2021-05-21'
    Stock1=yf.download(StockSymbol[i], start=formStart, end=formEnd ,group_by="ticker")
    Stock1['ROI']=(Stock1['Close'].shift(-1)-Stock1['Close'])/Stock1['Close']*100
    Stock1 = Stock1.dropna()
    Stock1.index=pd.to_datetime(Stock1.index)
    for j in range (i+1,len(StockSymbol)):
        formStart='2020-01-01'
        formEnd='2021-05-21'
        Stock2=yf.download(StockSymbol[j], start=formStart, end=formEnd ,group_by="ticker")
        Stock2['ROI']=(Stock2['Close'].shift(-1)-Stock2['Close'])/Stock2['Close']*100
        Stock2 = Stock2.dropna()
        Stock2.index=pd.to_datetime(Stock2.index)
        
        Stock1f=Stock1[formStart:formEnd]
        Stock2f=Stock2[formStart:formEnd]
        
        pairf=pd.concat([Stock1f.Close,Stock2f.Close],axis = 1)
        pairf.columns = [StockName[i],StockName[j]]
        
        Stock1f =  pairf[StockName[i]]  
        Stock2f = pairf[StockName[j]] 
        standardX=Stock1f/Stock1f[0]
        standardY=Stock2f/Stock2f[0]
        dis=np.sum((standardX-standardY)**2)
#         dis=SSD(Stock1f,Stock2f)
        
        Stock1flog=np.log(Stock1f)
        adfA=ADF(Stock1flog)
        
        retA=Stock1flog.diff()[1:]
        adfretA=ADF(retA)
        
        Stock2flog=np.log(Stock2f)
        adfB=ADF(Stock2flog)
        
        retB=Stock2flog.diff()[1:]
        adfretB=ADF(retB)
        
        Stock1flog = Stock1flog.dropna()
        Stock2flog = Stock2flog.dropna()
        
        model=sm.OLS(Stock1flog,sm.add_constant(Stock2flog))
        results=model.fit()
        
        alpha=results.params[0]  
        beta=results.params[1]

        spread=Stock1flog-beta*Stock2flog-alpha

        adfSpread=ADF(spread, trend='nc') 

        standardA= Stock1f/Stock1f[0]
        standardB= Stock2f/Stock2f[0]
        SSD_pair=standardA-standardB

        meanSSD_pair=np.mean(SSD_pair)
        sdSSD_pair=np.std(SSD_pair)
        thresholdUp=meanSSD_pair+1.5*sdSSD_pair
        thresholdDown=meanSSD_pair-1.5*sdSSD_pair
        
        tradStart='2021-01-01'
        tradEnd='2021-05-21'
        
        Stock1t=Stock1[tradStart:tradEnd].Close
        Stock2t=Stock1[tradStart:tradEnd].Close
        
        data = pd.concat([Stock1t,Stock2t],axis=1).dropna()
        data.columns=['X','Y']
        standardX=data.X/data.X[0]
        standardY=data.Y/data.Y[0]
        TradSpread=standardX-standardY
        

        spreadf=Stock1flog-beta*Stock2flog-alpha
        mu=np.mean(spreadf)
        sd=np.std(spreadf)

        CoSpreadT=np.log(Stock1t)-beta*np.log(Stock2t)-alpha
        
        formStart='2020-01-01'
        formEnd='2020-12-31'
        tradeStart='2021-01-01'
        tradeEnd='2021-05-21'

        priceA= Stock2.Close
        priceB=Stock1.Close
        priceAf=priceA[formStart:formEnd]
        priceBf=priceB[formStart:formEnd]
        priceAt=priceA[tradeStart:tradeEnd]
        priceBt=priceB[tradeStart:tradeEnd]

        pt=PairTrading()
        SSD=pt.SSD(priceAf,priceBf)

        SSDspread=pt.SSDSpread(priceAf,priceBf)
            
        print(str(StockName[i] + "與" + StockName[j] + "："))    
            
        coefficients=pt.cointegration(priceAf,priceBf)
        
        CoSpreadF=pt.CointegrationSpread(priceA,priceB,formStart,formEnd,formStart,formEnd)

        CoSpreadTr=pt.CointegrationSpread(priceA,priceB,formStart,formEnd,tradeStart,tradeEnd)
        
        bound=pt.calBound(priceA,priceB,'Cointegration',formStart,formEnd,width=1.2)
        
        if (coefficients[2] == True):
            mu=np.mean(CoSpreadF)
            sd=np.std(CoSpreadF)

            level=(float('-inf'),mu-2.5*sd,
                mu-1.5*sd,mu-0.2*sd,
                mu+0.2*sd,mu+1.5*sd,
                mu+2.5*sd,
                float('inf'))

            prcLevel=pd.cut(CoSpreadTr,level,labels=False)-3

            signal=TradeSig(prcLevel)

            position=[signal[0]]
            ns=len(signal)

            for g in range(1,ns):
                position.append(position[-1])
                if signal[g]==1:
                    position[g]=1
                elif signal[g]==-2:
                    position[g]=-1
                elif signal[g]==-1 and position[g-1]==1:
                    position[g]=0
                elif signal[g]==2 and position[g-1]==-1:
                    position[g]=0
                elif signal[g]==3:
                    position[g]=0
                elif signal[g]==-3:
                    position[g]=0

            position=pd.Series(position,index=CoSpreadT.index)

            account1=TradeSim(Stock2t,Stock1t,position)
            account1.tail() 
            print(str(StockName[i]) + "與" + str(StockName[j]) + "：" + str(account1.loc['2021-05-19','Asset']))
            txtarry.append(str(StockName[i]) + "與" + str(StockName[j]) + "：" + str(account1.loc['2021-05-19','Asset']))
        else:
            pass
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW1216：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004145
#             Coefficients of regression:
#             Intercept: 1.017743
#             Beta: 0.649454
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004145
#             Coefficients of regression:
#             Intercept: 1.017743
#             Beta: 0.649454
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004145
#             Coefficients of regression:
#             Intercept: 1.017743
#             Beta: 0.649454
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004145
#             Coefficients of regression:
#             Intercept: 1.017743
#             Beta: 0.649454
#
# TW1102與TW1216：6365.091564676841
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW1301：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.031565
#             Coefficients of regression:
#             Intercept: 1.283243
#             Beta: 0.559074
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.031565
#             Coefficients of regression:
#             Intercept: 1.283243
#             Beta: 0.559074
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.031565
#             Coefficients of regression:
#             Intercept: 1.283243
#             Beta: 0.559074
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.031565
#             Coefficients of regression:
#             Intercept: 1.283243
#             Beta: 0.559074
#
# TW1102與TW1301：16994.80040384739
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW1303：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.014021
#             Coefficients of regression:
#             Intercept: 1.281115
#             Beta: 0.598162
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.014021
#             Coefficients of regression:
#             Intercept: 1.281115
#             Beta: 0.598162
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.014021
#             Coefficients of regression:
#             Intercept: 1.281115
#             Beta: 0.598162
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.014021
#             Coefficients of regression:
#             Intercept: 1.281115
#             Beta: 0.598162
#
# TW1102與TW1303：4548.646489831794
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW1326：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW1402：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044890
#             Coefficients of regression:
#             Intercept: 1.690618
#             Beta: 0.630133
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044890
#             Coefficients of regression:
#             Intercept: 1.690618
#             Beta: 0.630133
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044890
#             Coefficients of regression:
#             Intercept: 1.690618
#             Beta: 0.630133
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044890
#             Coefficients of regression:
#             Intercept: 1.690618
#             Beta: 0.630133
#
# TW1102與TW1402：31212.563734283613
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2002：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2105：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2207：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043201
#             Coefficients of regression:
#             Intercept: 2.513834
#             Beta: 0.194941
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043201
#             Coefficients of regression:
#             Intercept: 2.513834
#             Beta: 0.194941
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043201
#             Coefficients of regression:
#             Intercept: 2.513834
#             Beta: 0.194941
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043201
#             Coefficients of regression:
#             Intercept: 2.513834
#             Beta: 0.194941
#
# TW1102與TW2207：-11251.519155684393
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2227：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004173
#             Coefficients of regression:
#             Intercept: 0.822019
#             Beta: 0.530707
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004173
#             Coefficients of regression:
#             Intercept: 0.822019
#             Beta: 0.530707
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004173
#             Coefficients of regression:
#             Intercept: 0.822019
#             Beta: 0.530707
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004173
#             Coefficients of regression:
#             Intercept: 0.822019
#             Beta: 0.530707
#
# TW1102與TW2227：4529.416737042833
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2301：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044803
#             Coefficients of regression:
#             Intercept: 1.682650
#             Beta: 0.541860
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044803
#             Coefficients of regression:
#             Intercept: 1.682650
#             Beta: 0.541860
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044803
#             Coefficients of regression:
#             Intercept: 1.682650
#             Beta: 0.541860
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044803
#             Coefficients of regression:
#             Intercept: 1.682650
#             Beta: 0.541860
#
# TW1102與TW2301：14575.173611336795
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2303：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.036343
#             Coefficients of regression:
#             Intercept: 3.839562
#             Beta: -0.024647
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.036343
#             Coefficients of regression:
#             Intercept: 3.839562
#             Beta: -0.024647
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.036343
#             Coefficients of regression:
#             Intercept: 3.839562
#             Beta: -0.024647
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.036343
#             Coefficients of regression:
#             Intercept: 3.839562
#             Beta: -0.024647
#
# TW1102與TW2303：-14516.14563486178
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2308：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034175
#             Coefficients of regression:
#             Intercept: 3.775583
#             Beta: -0.002183
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034175
#             Coefficients of regression:
#             Intercept: 3.775583
#             Beta: -0.002183
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034175
#             Coefficients of regression:
#             Intercept: 3.775583
#             Beta: -0.002183
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034175
#             Coefficients of regression:
#             Intercept: 3.775583
#             Beta: -0.002183
#
# TW1102與TW2308：-20371.55531256646
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2317：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2330：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.033624
#             Coefficients of regression:
#             Intercept: 3.906464
#             Beta: -0.024021
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.033624
#             Coefficients of regression:
#             Intercept: 3.906464
#             Beta: -0.024021
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.033624
#             Coefficients of regression:
#             Intercept: 3.906464
#             Beta: -0.024021
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.033624
#             Coefficients of regression:
#             Intercept: 3.906464
#             Beta: -0.024021
#
# TW1102與TW2330：-13549.95825170388
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2352：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2354：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.023800
#             Coefficients of regression:
#             Intercept: 1.164038
#             Beta: 0.649978
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.023800
#             Coefficients of regression:
#             Intercept: 1.164038
#             Beta: 0.649978
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.023800
#             Coefficients of regression:
#             Intercept: 1.164038
#             Beta: 0.649978
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.023800
#             Coefficients of regression:
#             Intercept: 1.164038
#             Beta: 0.649978
#
# TW1102與TW2354：24885.574403808045
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2357：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044889
#             Coefficients of regression:
#             Intercept: 3.300098
#             Beta: 0.085654
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044889
#             Coefficients of regression:
#             Intercept: 3.300098
#             Beta: 0.085654
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044889
#             Coefficients of regression:
#             Intercept: 3.300098
#             Beta: 0.085654
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044889
#             Coefficients of regression:
#             Intercept: 3.300098
#             Beta: 0.085654
#
# TW1102與TW2357：6208.679466596688
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2382：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034179
#             Coefficients of regression:
#             Intercept: 3.767390
#             Beta: -0.000708
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034179
#             Coefficients of regression:
#             Intercept: 3.767390
#             Beta: -0.000708
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034179
#             Coefficients of regression:
#             Intercept: 3.767390
#             Beta: -0.000708
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034179
#             Coefficients of regression:
#             Intercept: 3.767390
#             Beta: -0.000708
#
# TW1102與TW2382：-17118.057623676257
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2395：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041820
#             Coefficients of regression:
#             Intercept: 3.130218
#             Beta: 0.112499
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041820
#             Coefficients of regression:
#             Intercept: 3.130218
#             Beta: 0.112499
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041820
#             Coefficients of regression:
#             Intercept: 3.130218
#             Beta: 0.112499
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041820
#             Coefficients of regression:
#             Intercept: 3.130218
#             Beta: 0.112499
#
# TW1102與TW2395：13878.844063608965
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2408：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2409：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042250
#             Coefficients of regression:
#             Intercept: 3.647589
#             Beta: 0.050790
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042250
#             Coefficients of regression:
#             Intercept: 3.647589
#             Beta: 0.050790
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042250
#             Coefficients of regression:
#             Intercept: 3.647589
#             Beta: 0.050790
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042250
#             Coefficients of regression:
#             Intercept: 3.647589
#             Beta: 0.050790
#
# TW1102與TW2409：16853.81347720629
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2412：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003615
#             Coefficients of regression:
#             Intercept: -3.986326
#             Beta: 1.651363
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003615
#             Coefficients of regression:
#             Intercept: -3.986326
#             Beta: 1.651363
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003615
#             Coefficients of regression:
#             Intercept: -3.986326
#             Beta: 1.651363
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003615
#             Coefficients of regression:
#             Intercept: -3.986326
#             Beta: 1.651363
#
# TW1102與TW2412：-1981.7149841997307
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2454：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034386
#             Coefficients of regression:
#             Intercept: 3.848926
#             Beta: -0.013506
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034386
#             Coefficients of regression:
#             Intercept: 3.848926
#             Beta: -0.013506
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034386
#             Coefficients of regression:
#             Intercept: 3.848926
#             Beta: -0.013506
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034386
#             Coefficients of regression:
#             Intercept: 3.848926
#             Beta: -0.013506
#
# TW1102與TW2454：-13469.09506509942
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2474：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009117
#             Coefficients of regression:
#             Intercept: 1.865153
#             Beta: 0.355171
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009117
#             Coefficients of regression:
#             Intercept: 1.865153
#             Beta: 0.355171
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009117
#             Coefficients of regression:
#             Intercept: 1.865153
#             Beta: 0.355171
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009117
#             Coefficients of regression:
#             Intercept: 1.865153
#             Beta: 0.355171
#
# TW1102與TW2474：-5361.892478543508
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2609：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034087
#             Coefficients of regression:
#             Intercept: 3.766608
#             Beta: -0.001062
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034087
#             Coefficients of regression:
#             Intercept: 3.766608
#             Beta: -0.001062
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034087
#             Coefficients of regression:
#             Intercept: 3.766608
#             Beta: -0.001062
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034087
#             Coefficients of regression:
#             Intercept: 3.766608
#             Beta: -0.001062
#
# TW1102與TW2609：-20838.312368191488
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2610：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2801：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2823：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.005047
#             Coefficients of regression:
#             Intercept: 2.503505
#             Beta: 0.420452
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.005047
#             Coefficients of regression:
#             Intercept: 2.503505
#             Beta: 0.420452
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.005047
#             Coefficients of regression:
#             Intercept: 2.503505
#             Beta: 0.420452
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.005047
#             Coefficients of regression:
#             Intercept: 2.503505
#             Beta: 0.420452
#
# TW1102與TW2823：-4079.30007066729
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2880：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042859
#             Coefficients of regression:
#             Intercept: 1.760880
#             Beta: 0.686228
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042859
#             Coefficients of regression:
#             Intercept: 1.760880
#             Beta: 0.686228
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042859
#             Coefficients of regression:
#             Intercept: 1.760880
#             Beta: 0.686228
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.042859
#             Coefficients of regression:
#             Intercept: 1.760880
#             Beta: 0.686228
#
# TW1102與TW2880：5024.700832261762
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2881：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2882：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.016660
#             Coefficients of regression:
#             Intercept: 0.547009
#             Beta: 0.873332
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.016660
#             Coefficients of regression:
#             Intercept: 0.547009
#             Beta: 0.873332
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.016660
#             Coefficients of regression:
#             Intercept: 0.547009
#             Beta: 0.873332
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.016660
#             Coefficients of regression:
#             Intercept: 0.547009
#             Beta: 0.873332
#
# TW1102與TW2882：2296.1243664918584
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2883：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000026
#             Coefficients of regression:
#             Intercept: 2.135778
#             Beta: 0.748469
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000026
#             Coefficients of regression:
#             Intercept: 2.135778
#             Beta: 0.748469
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000026
#             Coefficients of regression:
#             Intercept: 2.135778
#             Beta: 0.748469
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000026
#             Coefficients of regression:
#             Intercept: 2.135778
#             Beta: 0.748469
#
# TW1102與TW2883：1579.6040255694825
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2884：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032736
#             Coefficients of regression:
#             Intercept: 2.126568
#             Beta: 0.505491
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032736
#             Coefficients of regression:
#             Intercept: 2.126568
#             Beta: 0.505491
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032736
#             Coefficients of regression:
#             Intercept: 2.126568
#             Beta: 0.505491
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032736
#             Coefficients of regression:
#             Intercept: 2.126568
#             Beta: 0.505491
#
# TW1102與TW2884：-653.141846358194
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2885：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2886：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.017708
#             Coefficients of regression:
#             Intercept: 1.731224
#             Beta: 0.597648
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.017708
#             Coefficients of regression:
#             Intercept: 1.731224
#             Beta: 0.597648
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.017708
#             Coefficients of regression:
#             Intercept: 1.731224
#             Beta: 0.597648
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.017708
#             Coefficients of regression:
#             Intercept: 1.731224
#             Beta: 0.597648
#
# TW1102與TW2886：5048.81853255321
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2887：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.046483
#             Coefficients of regression:
#             Intercept: 2.229591
#             Beta: 0.599184
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.046483
#             Coefficients of regression:
#             Intercept: 2.229591
#             Beta: 0.599184
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.046483
#             Coefficients of regression:
#             Intercept: 2.229591
#             Beta: 0.599184
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.046483
#             Coefficients of regression:
#             Intercept: 2.229591
#             Beta: 0.599184
#
# TW1102與TW2887：1184.866329644341
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2890：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044097
#             Coefficients of regression:
#             Intercept: 2.378898
#             Beta: 0.568849
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044097
#             Coefficients of regression:
#             Intercept: 2.378898
#             Beta: 0.568849
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044097
#             Coefficients of regression:
#             Intercept: 2.378898
#             Beta: 0.568849
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044097
#             Coefficients of regression:
#             Intercept: 2.378898
#             Beta: 0.568849
#
# TW1102與TW2890：14842.88566158223
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2891：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004701
#             Coefficients of regression:
#             Intercept: 2.002790
#             Beta: 0.590671
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004701
#             Coefficients of regression:
#             Intercept: 2.002790
#             Beta: 0.590671
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004701
#             Coefficients of regression:
#             Intercept: 2.002790
#             Beta: 0.590671
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.004701
#             Coefficients of regression:
#             Intercept: 2.002790
#             Beta: 0.590671
#
# TW1102與TW2891：-1001193.8625338379
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2892：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000362
#             Coefficients of regression:
#             Intercept: 1.671407
#             Beta: 0.683043
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000362
#             Coefficients of regression:
#             Intercept: 1.671407
#             Beta: 0.683043
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000362
#             Coefficients of regression:
#             Intercept: 1.671407
#             Beta: 0.683043
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000362
#             Coefficients of regression:
#             Intercept: 1.671407
#             Beta: 0.683043
#
# TW1102與TW2892：4486.19376313762
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW2912：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.020899
#             Coefficients of regression:
#             Intercept: 0.593519
#             Beta: 0.561628
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.020899
#             Coefficients of regression:
#             Intercept: 0.593519
#             Beta: 0.561628
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.020899
#             Coefficients of regression:
#             Intercept: 0.593519
#             Beta: 0.561628
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.020899
#             Coefficients of regression:
#             Intercept: 0.593519
#             Beta: 0.561628
#
# TW1102與TW2912：-2503.2973634880036
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW3045：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032026
#             Coefficients of regression:
#             Intercept: 0.530905
#             Beta: 0.696634
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032026
#             Coefficients of regression:
#             Intercept: 0.530905
#             Beta: 0.696634
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032026
#             Coefficients of regression:
#             Intercept: 0.530905
#             Beta: 0.696634
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032026
#             Coefficients of regression:
#             Intercept: 0.530905
#             Beta: 0.696634
#
# TW1102與TW3045：933.9802722599125
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW3481：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041110
#             Coefficients of regression:
#             Intercept: 3.668831
#             Beta: 0.044814
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041110
#             Coefficients of regression:
#             Intercept: 3.668831
#             Beta: 0.044814
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041110
#             Coefficients of regression:
#             Intercept: 3.668831
#             Beta: 0.044814
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041110
#             Coefficients of regression:
#             Intercept: 3.668831
#             Beta: 0.044814
#
# TW1102與TW3481：7226.1586114435195
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW4904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.040871
#             Coefficients of regression:
#             Intercept: 0.627221
#             Beta: 0.753940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.040871
#             Coefficients of regression:
#             Intercept: 0.627221
#             Beta: 0.753940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.040871
#             Coefficients of regression:
#             Intercept: 0.627221
#             Beta: 0.753940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.040871
#             Coefficients of regression:
#             Intercept: 0.627221
#             Beta: 0.753940
#
# TW1102與TW4904：6701.693394745293
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW4938：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.019202
#             Coefficients of regression:
#             Intercept: 1.323926
#             Beta: 0.587086
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.019202
#             Coefficients of regression:
#             Intercept: 1.323926
#             Beta: 0.587086
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.019202
#             Coefficients of regression:
#             Intercept: 1.323926
#             Beta: 0.587086
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.019202
#             Coefficients of regression:
#             Intercept: 1.323926
#             Beta: 0.587086
#
# TW1102與TW4938：19681.55698987929
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW5880：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.029695
#             Coefficients of regression:
#             Intercept: 1.636951
#             Beta: 0.712288
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.029695
#             Coefficients of regression:
#             Intercept: 1.636951
#             Beta: 0.712288
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.029695
#             Coefficients of regression:
#             Intercept: 1.636951
#             Beta: 0.712288
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.029695
#             Coefficients of regression:
#             Intercept: 1.636951
#             Beta: 0.712288
#
# TW1102與TW5880：8665.078542756091
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW1102與TW9904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007695
#             Coefficients of regression:
#             Intercept: 2.446134
#             Beta: 0.390429
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007695
#             Coefficients of regression:
#             Intercept: 2.446134
#             Beta: 0.390429
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007695
#             Coefficients of regression:
#             Intercept: 2.446134
#             Beta: 0.390429
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007695
#             Coefficients of regression:
#             Intercept: 2.446134
#             Beta: 0.390429
#
# TW1102與TW9904：2870.0034899253515
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW1301：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW1303：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW1326：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW1402：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2002：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2105：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2207：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2227：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2301：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2303：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2308：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2317：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2330：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2352：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2354：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2357：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2382：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2395：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2408：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2409：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2412：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2454：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2474：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000143
#             Coefficients of regression:
#             Intercept: 1.482525
#             Beta: 0.513641
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000143
#             Coefficients of regression:
#             Intercept: 1.482525
#             Beta: 0.513641
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000143
#             Coefficients of regression:
#             Intercept: 1.482525
#             Beta: 0.513641
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000143
#             Coefficients of regression:
#             Intercept: 1.482525
#             Beta: 0.513641
#
# TW1216與TW2474：-9819.767003948218
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2609：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2610：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2801：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2823：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2880：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2881：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2882：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2883：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2884：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2885：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2886：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.049189
#             Coefficients of regression:
#             Intercept: 0.998853
#             Beta: 0.949548
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.049189
#             Coefficients of regression:
#             Intercept: 0.998853
#             Beta: 0.949548
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.049189
#             Coefficients of regression:
#             Intercept: 0.998853
#             Beta: 0.949548
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.049189
#             Coefficients of regression:
#             Intercept: 0.998853
#             Beta: 0.949548
#
# TW1216與TW2886：13496.37925050978
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2887：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2890：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2891：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2892：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW3008：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002382
#             Coefficients of regression:
#             Intercept: 1.095277
#             Beta: 0.379940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002382
#             Coefficients of regression:
#             Intercept: 1.095277
#             Beta: 0.379940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002382
#             Coefficients of regression:
#             Intercept: 1.095277
#             Beta: 0.379940
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002382
#             Coefficients of regression:
#             Intercept: 1.095277
#             Beta: 0.379940
#
# TW1216與TW3008：-1433.9948301594704
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW3045：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007238
#             Coefficients of regression:
#             Intercept: -0.750997
#             Beta: 1.072944
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007238
#             Coefficients of regression:
#             Intercept: -0.750997
#             Beta: 1.072944
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007238
#             Coefficients of regression:
#             Intercept: -0.750997
#             Beta: 1.072944
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007238
#             Coefficients of regression:
#             Intercept: -0.750997
#             Beta: 1.072944
#
# TW1216與TW3045：5326.668422670977
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW4904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.010814
#             Coefficients of regression:
#             Intercept: 0.113522
#             Beta: 0.989090
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.010814
#             Coefficients of regression:
#             Intercept: 0.113522
#             Beta: 0.989090
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.010814
#             Coefficients of regression:
#             Intercept: 0.113522
#             Beta: 0.989090
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.010814
#             Coefficients of regression:
#             Intercept: 0.113522
#             Beta: 0.989090
#
# TW1216與TW4904：6890.734350032872
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW1216與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW1303：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW1326：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002379
#             Coefficients of regression:
#             Intercept: 0.441147
#             Beta: 0.928635
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002379
#             Coefficients of regression:
#             Intercept: 0.441147
#             Beta: 0.928635
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002379
#             Coefficients of regression:
#             Intercept: 0.441147
#             Beta: 0.928635
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.002379
#             Coefficients of regression:
#             Intercept: 0.441147
#             Beta: 0.928635
#
# TW1301與TW1326：10041.246835186961
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW1402：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2002：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044084
#             Coefficients of regression:
#             Intercept: 1.792839
#             Beta: 0.866448
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044084
#             Coefficients of regression:
#             Intercept: 1.792839
#             Beta: 0.866448
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044084
#             Coefficients of regression:
#             Intercept: 1.792839
#             Beta: 0.866448
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044084
#             Coefficients of regression:
#             Intercept: 1.792839
#             Beta: 0.866448
#
# TW1301與TW2002：17749.75599277322
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2105：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2207：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2227：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2301：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2303：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2308：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2317：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2330：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2352：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044452
#             Coefficients of regression:
#             Intercept: 3.509534
#             Beta: 0.315732
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044452
#             Coefficients of regression:
#             Intercept: 3.509534
#             Beta: 0.315732
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044452
#             Coefficients of regression:
#             Intercept: 3.509534
#             Beta: 0.315732
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044452
#             Coefficients of regression:
#             Intercept: 3.509534
#             Beta: 0.315732
#
# TW1301與TW2352：167721.78853346134
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2354：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2357：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2382：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2395：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047883
#             Coefficients of regression:
#             Intercept: 3.320992
#             Beta: 0.198145
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047883
#             Coefficients of regression:
#             Intercept: 3.320992
#             Beta: 0.198145
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047883
#             Coefficients of regression:
#             Intercept: 3.320992
#             Beta: 0.198145
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047883
#             Coefficients of regression:
#             Intercept: 3.320992
#             Beta: 0.198145
#
# TW1301與TW2395：-35180.010314860614
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2408：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032235
#             Coefficients of regression:
#             Intercept: 2.736243
#             Beta: 0.408209
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032235
#             Coefficients of regression:
#             Intercept: 2.736243
#             Beta: 0.408209
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032235
#             Coefficients of regression:
#             Intercept: 2.736243
#             Beta: 0.408209
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.032235
#             Coefficients of regression:
#             Intercept: 2.736243
#             Beta: 0.408209
#
# TW1301與TW2408：15548.740185294766
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2409：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.045126
#             Coefficients of regression:
#             Intercept: 4.130251
#             Beta: 0.133807
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.045126
#             Coefficients of regression:
#             Intercept: 4.130251
#             Beta: 0.133807
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.045126
#             Coefficients of regression:
#             Intercept: 4.130251
#             Beta: 0.133807
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.045126
#             Coefficients of regression:
#             Intercept: 4.130251
#             Beta: 0.133807
#
# TW1301與TW2409：153548.0132882028
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2412：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2454：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2474：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2609：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037112
#             Coefficients of regression:
#             Intercept: 4.337112
#             Beta: 0.047999
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037112
#             Coefficients of regression:
#             Intercept: 4.337112
#             Beta: 0.047999
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037112
#             Coefficients of regression:
#             Intercept: 4.337112
#             Beta: 0.047999
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037112
#             Coefficients of regression:
#             Intercept: 4.337112
#             Beta: 0.047999
#
# TW1301與TW2609：57987.81336273032
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2610：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043466
#             Coefficients of regression:
#             Intercept: 3.732965
#             Beta: 0.330263
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043466
#             Coefficients of regression:
#             Intercept: 3.732965
#             Beta: 0.330263
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043466
#             Coefficients of regression:
#             Intercept: 3.732965
#             Beta: 0.330263
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.043466
#             Coefficients of regression:
#             Intercept: 3.732965
#             Beta: 0.330263
#
# TW1301與TW2610：10000.0
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2801：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2823：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.022567
#             Coefficients of regression:
#             Intercept: 2.449809
#             Beta: 0.662962
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.022567
#             Coefficients of regression:
#             Intercept: 2.449809
#             Beta: 0.662962
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.022567
#             Coefficients of regression:
#             Intercept: 2.449809
#             Beta: 0.662962
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.022567
#             Coefficients of regression:
#             Intercept: 2.449809
#             Beta: 0.662962
#
# TW1301與TW2823：5939.908463930362
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2880：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2881：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044191
#             Coefficients of regression:
#             Intercept: 0.261784
#             Beta: 1.112124
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044191
#             Coefficients of regression:
#             Intercept: 0.261784
#             Beta: 1.112124
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044191
#             Coefficients of regression:
#             Intercept: 0.261784
#             Beta: 1.112124
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.044191
#             Coefficients of regression:
#             Intercept: 0.261784
#             Beta: 1.112124
#
# TW1301與TW2881：-5644.916624292731
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2882：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2883：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2884：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2885：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2886：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2887：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2890：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2891：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2892：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW3045：
# [*********************100%***********************]  1 of 1 completed
# TW1301與TW3481：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037917
#             Coefficients of regression:
#             Intercept: 4.173479
#             Beta: 0.124036
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037917
#             Coefficients of regression:
#             Intercept: 4.173479
#             Beta: 0.124036
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.037917
#             Coefficients of regression:
# ...
#             Coefficients of regression:
#             Intercept: -0.682717
#             Beta: 0.880014
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.038469
#             Coefficients of regression:
#             Intercept: -0.682717
#             Beta: 0.880014
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.038469
#             Coefficients of regression:
#             Intercept: -0.682717
#             Beta: 0.880014
#
# TW2886與TW3045：6762.07510886871
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2886與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW2890：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW2891：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW2892：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW3045：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2887與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW2891：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW2892：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW3045：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2890與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW2892：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW3045：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2891與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW2912：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW3008：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW3045：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041837
#             Coefficients of regression:
#             Intercept: -0.396417
#             Beta: 0.745594
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041837
#             Coefficients of regression:
#             Intercept: -0.396417
#             Beta: 0.745594
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041837
#             Coefficients of regression:
#             Intercept: -0.396417
#             Beta: 0.745594
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.041837
#             Coefficients of regression:
#             Intercept: -0.396417
#             Beta: 0.745594
#
# TW2892與TW3045：11731.684302479698
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2892與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW3008：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.001825
#             Coefficients of regression:
#             Intercept: 2.753362
#             Beta: 0.350674
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.001825
#             Coefficients of regression:
#             Intercept: 2.753362
#             Beta: 0.350674
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.001825
#             Coefficients of regression:
#             Intercept: 2.753362
#             Beta: 0.350674
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.001825
#             Coefficients of regression:
#             Intercept: 2.753362
#             Beta: 0.350674
#
# TW2912與TW3008：116394.3581565657
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW3045：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009210
#             Coefficients of regression:
#             Intercept: 1.044999
#             Beta: 0.991224
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009210
#             Coefficients of regression:
#             Intercept: 1.044999
#             Beta: 0.991224
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009210
#             Coefficients of regression:
#             Intercept: 1.044999
#             Beta: 0.991224
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.009210
#             Coefficients of regression:
#             Intercept: 1.044999
#             Beta: 0.991224
#
# TW2912與TW3045：10000.0
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW4904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000931
#             Coefficients of regression:
#             Intercept: 1.444507
#             Beta: 1.009686
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000931
#             Coefficients of regression:
#             Intercept: 1.444507
#             Beta: 1.009686
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000931
#             Coefficients of regression:
#             Intercept: 1.444507
#             Beta: 1.009686
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.000931
#             Coefficients of regression:
#             Intercept: 1.444507
#             Beta: 1.009686
#
# TW2912與TW4904：15618.14155339729
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW2912與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW3045：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034911
#             Coefficients of regression:
#             Intercept: -2.750624
#             Beta: 2.369662
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034911
#             Coefficients of regression:
#             Intercept: -2.750624
#             Beta: 2.369662
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034911
#             Coefficients of regression:
#             Intercept: -2.750624
#             Beta: 2.369662
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.034911
#             Coefficients of regression:
#             Intercept: -2.750624
#             Beta: 2.369662
#
# TW3008與TW3045：-1819323.7568398416
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW3008與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW3481：
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW4904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007457
#             Coefficients of regression:
#             Intercept: 1.117169
#             Beta: 0.847004
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007457
#             Coefficients of regression:
#             Intercept: 1.117169
#             Beta: 0.847004
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007457
#             Coefficients of regression:
#             Intercept: 1.117169
#             Beta: 0.847004
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.007457
#             Coefficients of regression:
#             Intercept: 1.117169
#             Beta: 0.847004
#
# TW3045與TW4904：11756.368731115479
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW3045與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW3711：
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW3481與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW3711與TW4904：
# [*********************100%***********************]  1 of 1 completed
# TW3711與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW3711與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW3711與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW3711與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW4904與TW4938：
# [*********************100%***********************]  1 of 1 completed
# TW4904與TW5880：
# [*********************100%***********************]  1 of 1 completed
# TW4904與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW4904與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW4938與TW5880：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.021325
#             Coefficients of regression:
#             Intercept: 1.507281
#             Beta: 0.887121
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.021325
#             Coefficients of regression:
#             Intercept: 1.507281
#             Beta: 0.887121
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.021325
#             Coefficients of regression:
#             Intercept: 1.507281
#             Beta: 0.887121
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.021325
#             Coefficients of regression:
#             Intercept: 1.507281
#             Beta: 0.887121
#
# TW4938與TW5880：13177.741692053503
# [*********************100%***********************]  1 of 1 completed
# TW4938與TW6505：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003154
#             Coefficients of regression:
#             Intercept: 1.422295
#             Beta: 0.613476
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003154
#             Coefficients of regression:
#             Intercept: 1.422295
#             Beta: 0.613476
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003154
#             Coefficients of regression:
#             Intercept: 1.422295
#             Beta: 0.613476
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.003154
#             Coefficients of regression:
#             Intercept: 1.422295
#             Beta: 0.613476
#
# TW4938與TW6505：34416.92665447289
# [*********************100%***********************]  1 of 1 completed
# TW4938與TW9904：
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047235
#             Coefficients of regression:
#             Intercept: 3.238134
#             Beta: 0.272111
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047235
#             Coefficients of regression:
#             Intercept: 3.238134
#             Beta: 0.272111
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047235
#             Coefficients of regression:
#             Intercept: 3.238134
#             Beta: 0.272111
#
# 交易價格具有協整關係.
#             P-value of ADF test: 0.047235
#             Coefficients of regression:
#             Intercept: 3.238134
#             Beta: 0.272111
#
# TW4938與TW9904：-21077.62058727964
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW5880與TW6505：
# [*********************100%***********************]  1 of 1 completed
# TW5880與TW9904：
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TW6505與TW9904：
# [*********************100%***********************]  1 of 1 completed

# %%
txtarry
# Out:
# ['TW1102與TW1216：6365.091564676841',
#  'TW1102與TW1301：16994.80040384739',
#  'TW1102與TW1303：4548.646489831794',
#  'TW1102與TW1402：31212.563734283613',
#  'TW1102與TW2207：-11251.519155684393',
#  'TW1102與TW2227：4529.416737042833',
#  'TW1102與TW2301：14575.173611336795',
#  'TW1102與TW2303：-14516.14563486178',
#  'TW1102與TW2308：-20371.55531256646',
#  'TW1102與TW2330：-13549.95825170388',
#  'TW1102與TW2354：24885.574403808045',
#  'TW1102與TW2357：6208.679466596688',
#  'TW1102與TW2382：-17118.057623676257',
#  'TW1102與TW2395：13878.844063608965',
#  'TW1102與TW2409：16853.81347720629',
#  'TW1102與TW2412：-1981.7149841997307',
#  'TW1102與TW2454：-13469.09506509942',
#  'TW1102與TW2474：-5361.892478543508',
#  'TW1102與TW2609：-20838.312368191488',
#  'TW1102與TW2823：-4079.30007066729',
#  'TW1102與TW2880：5024.700832261762',
#  'TW1102與TW2882：2296.1243664918584',
#  'TW1102與TW2883：1579.6040255694825',
#  'TW1102與TW2884：-653.141846358194',
#  'TW1102與TW2886：5048.81853255321',
#  'TW1102與TW2887：1184.866329644341',
#  'TW1102與TW2890：14842.88566158223',
#  'TW1102與TW2891：-1001193.8625338379',
#  'TW1102與TW2892：4486.19376313762',
#  'TW1102與TW2912：-2503.2973634880036',
#  'TW1102與TW3045：933.9802722599125',
#  'TW1102與TW3481：7226.1586114435195',
#  'TW1102與TW4904：6701.693394745293',
#  'TW1102與TW4938：19681.55698987929',
#  'TW1102與TW5880：8665.078542756091',
#  'TW1102與TW9904：2870.0034899253515',
#  'TW1216與TW2474：-9819.767003948218',
#  'TW1216與TW2886：13496.37925050978',
#  'TW1216與TW3008：-1433.9948301594704',
#  'TW1216與TW3045：5326.668422670977',
#  'TW1216與TW4904：6890.734350032872',
#  'TW1301與TW1326：10041.246835186961',
#  'TW1301與TW2002：17749.75599277322',
#  'TW1301與TW2352：167721.78853346134',
#  'TW1301與TW2395：-35180.010314860614',
#  'TW1301與TW2408：15548.740185294766',
#  'TW1301與TW2409：153548.0132882028',
#  'TW1301與TW2609：57987.81336273032',
#  'TW1301與TW2610：10000.0',
#  'TW1301與TW2823：5939.908463930362',
#  'TW1301與TW2881：-5644.916624292731',
#  'TW1301與TW3481：81778.6888541634',
#  'TW1303與TW2317：10000.0',
#  'TW1303與TW2408：-37421.498739963805',
#  'TW1303與TW2823：7265.296079439926',
#  'TW1303與TW2881：19996.819164451328',
#  'TW1303與TW3711：38767.36760236829',
#  'TW1303與TW6505：12659.138520022156',
#  'TW1326與TW2408：86336.06698934169',
#  'TW1402與TW2207：7320.9710309660295',
#  'TW1402與TW2227：10328.859096074972',
#  'TW1402與TW2301：-4049.258907332667',
#  'TW1402與TW2303：-15562.852893823445',
#  'TW1402與TW2308：-6541.1615125875105',
#  'TW1402與TW2317：10000.0',
#  'TW1402與TW2330：-2905.405681761389',
#  'TW1402與TW2382：28172.329811345946',
#  'TW1402與TW2395：20007.822013695026',
#  'TW1402與TW2409：38233.84959153496',
#  'TW1402與TW2412：73398.14911662717',
#  'TW1402與TW2454：-6979.107115814986',
#  'TW1402與TW2609：35655.764119325846',
#  'TW1402與TW2823：25770.399406403332',
#  'TW1402與TW2881：1378.6715507805638',
#  'TW1402與TW2882：13178.445302595297',
#  'TW1402與TW2883：8997.945141896838',
#  'TW1402與TW2884：10466.102028533292',
#  'TW1402與TW2887：13799.832696952391',
#  'TW1402與TW2892：13228.60121411283',
#  'TW1402與TW3481：38865.385895065905',
#  'TW1402與TW3711：17591.883671710675',
#  'TW1402與TW4938：6297.734566504805',
#  'TW1402與TW5880：33513.87068216113',
#  'TW1402與TW6505：18676.30329802967',
#  'TW2105與TW2303：-34136.91057064774',
#  'TW2105與TW2352：-12390.47412537373',
#  'TW2105與TW2409：-14975.230345772929',
#  'TW2105與TW2610：25618.229960850033',
#  'TW2105與TW2885：12182.46898741246',
#  'TW2105與TW3481：-11879.375778887537',
#  'TW2207與TW2454：-276565.38726703543',
#  'TW2207與TW5880：240967.98121935688',
#  'TW2227與TW2301：10000.0',
#  'TW2227與TW2412：10000.0',
#  'TW2227與TW2882：20195.707010384183',
#  'TW2227與TW2883：79847.32287865994',
#  'TW2227與TW2884：27942.37852344103',
#  'TW2227與TW2892：-1293.2475850149058',
#  'TW2227與TW5880：10000.0',
#  'TW2301與TW2412：10000.0',
#  'TW2301與TW2881：3467.3044385660905',
#  'TW2301與TW2882：10000.00850074424',
#  'TW2301與TW2883：10553.477024512133',
#  'TW2301與TW4938：18538.336934052408',
#  'TW2301與TW5880：10000.0',
#  'TW2301與TW6505：13861.666166410432',
#  'TW2303與TW2609：-8453.08402677317',
#  'TW2308與TW2395：-424272.64757294115',
#  'TW2317與TW2352：10000.0',
#  'TW2317與TW2395：10000.0',
#  'TW2317與TW2409：-1798.4901169726509',
#  'TW2317與TW2610：72107.62837051111',
#  'TW2317與TW2881：7924.893012974877',
#  'TW2317與TW2885：12620.711361980066',
#  'TW2317與TW3481：-2662.526362722623',
#  'TW2317與TW3711：6855.724735197611',
#  'TW2352與TW2610：11063.740484519367',
#  'TW2354與TW2357：-24656.91113779298',
#  'TW2354與TW2382：-21234.778446384764',
#  'TW2354與TW2395：-17572.989361776155',
#  'TW2354與TW2409：-43940.21876014798',
#  'TW2354與TW2412：132715.48920156062',
#  'TW2354與TW2454：-39693.05816615268',
#  'TW2354與TW2474：10000.0',
#  'TW2354與TW2609：-43945.84826321024',
#  'TW2354與TW2880：-9967.715742457309',
#  'TW2354與TW2884：-14931.712715453177',
#  'TW2354與TW2886：10046.854001762462',
#  'TW2354與TW2890：10000.0',
#  'TW2354與TW2891：8032.702841637074',
#  'TW2354與TW2892：10000.0',
#  'TW2354與TW2912：10000.0',
#  'TW2354與TW3008：10000.0',
#  'TW2354與TW3045：-77791.12885979156',
#  'TW2354與TW3481：-45761.25160705435',
#  'TW2354與TW5880：12244.76076303667',
#  'TW2382與TW2454：60490.05452431191',
#  'TW2409與TW2885：56740.20273764746',
#  'TW2412與TW3045：23710.57020731899',
#  'TW2474與TW2886：-1042.486481256783',
#  'TW2474與TW2891：11851.644926973851',
#  'TW2474與TW2912：-101816.51402618224',
#  'TW2474與TW3008：62277.31558799639',
#  'TW2474與TW3045：-108431.08859450277',
#  'TW2474與TW4904：53097.687633845955',
#  'TW2823與TW2881：10510.222141167324',
#  'TW2823與TW2882：8306.796616192616',
#  'TW2823與TW6505：3669.231613141368',
#  'TW2823與TW9904：9983.938838360307',
#  'TW2880與TW2886：9066.579071505024',
#  'TW2881與TW3481：-4046.407441280666',
#  'TW2881與TW3711：-3111.8979664972576',
#  'TW2882與TW2883：-6417.394751670072',
#  'TW2882與TW4938：-912596.4935114149',
#  'TW2882與TW5880：18092.221755806007',
#  'TW2882與TW6505：8205.331919917837',
#  'TW2883與TW4938：9553.9982793253',
#  'TW2883與TW6505：9935.991473767717',
#  'TW2885與TW3481：40266.15449926196',
#  'TW2886與TW3045：6762.07510886871',
#  'TW2892與TW3045：11731.684302479698',
#  'TW2912與TW3008：116394.3581565657',
#  'TW2912與TW3045：10000.0',
#  'TW2912與TW4904：15618.14155339729',
#  'TW3008與TW3045：-1819323.7568398416',
#  'TW3045與TW4904：11756.368731115479',
#  'TW4938與TW5880：13177.741692053503',
#  'TW4938與TW6505：34416.92665447289',
#  'TW4938與TW9904：-21077.62058727964']
